# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 5
sample_id = 4000
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 5:
# Samples: 10000
# Label Counts: {0: 1014, 1: 1014, 2: 952, 3: 1016, 4: 997, 5: 1025, 6: 980, 7: 977, 8: 1003, 9: 1022}
# First 20 Labels: [1, 8, 5, 1, 5, 7, 4, 3, 8, 2, 7, 2, 0, 1, 5, 9, 6, 2, 0, 8]
#
# Example of Image 4000:
# Image - Min Value: 0 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 7 Name: horse

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    #x = np.divide(x,np.max(x, axis=0))
    return x/np.max(x, axis=0)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# test
# [[[[208 183 153]
#    [ 24 183 235]
#    [ 52  50   5]
#    ...,
#    [  6 218  80]
#    [ 39 225 241]
#    [ 50 167 177]]
#
#   [[ 71  57 102]
#    [162 251  37]
#    [213 131 229]
#    ...,
#    [ 86 108 185]
#    [143  10  51]
#    [231 151 154]]
#
#   [[189   8  73]
#    [137 127  81]
#    [141 149  30]
#    ...,
#    [  9 205  68]
#    [ 21 236 120]
#    [146 247  35]]
#
#   ...,
#   [[195 133  77]
#    [186 152  62]
#    [ 25 171  99]
#    ...,
#    [132 160 214]
#    [  8 103 104]
#    [147 178 213]]
#
#   [[189  41  14]
#    [113 233  20]
#    [113 107  17]
#    ...,
#    [106 228   9]
#    [  0 234 237]
#    [ 41 166   9]]
#
#   [[131  22 180]
#    [118  52   8]
#    [178 215 240]
#    ...,
#    [ 20  40  33]
#    [254 113  35]
#    [149  41  43]]]
#
#
#  [[[173 150 168]
#    [ 78  14 165]
#    [216 110 197]
#    ...,
#    [141 165 113]
#    [147  38 248]
#    [108  88 121]]
#
#   [[169 242 139]
#    [215 141  23]
#    [105  55 255]
#    ...,
#    [181 196  76]
#    [177 219 249]
#    [104  47  68]]
#
#   [[153  78 189]
#    [ 73 127 130]
#    [100  55 164]
#    ...,
#    [ 95 104 160]
#    [137 223 118]
#    [176 240 205]]
#
#   ...,
#   [[ 91 225 214]
#    [250 118 187]
#    [122 150 117]
#    ...,
#    [214 135 129]
#    [224 251 194]
#    [106  55  15]]
#
#   [[240 201 246]
#    [193 168 167]
#    [ 51 235  25]
#    ...,
#    [ 91 247 191]
#    [236 172  16]
#    [207 176 112]]
#
#   [[ 82 213 140]
#    [  6 219  34]
#    [135 170 200]
#    ...,
#    [255  47 161]
#    [224 117 120]
#    [235 136 227]]]
#
#
#  [[[195 242  53]
#    [199  46 164]
#    [198  17 126]
#    ...,
#    [197 142  50]
#    [ 60 166 178]
#    [204 229  18]]
#
#   [[ 16   2 134]
#    [  4 144 172]
#    [ 42  40  38]
#    ...,
#    [ 59 175 113]
#    [ 91 108  91]
#    [216 200  70]]
#
#   [[140 219  22]
#    [ 88  83   4]
#    [254 115 185]
#    ...,
#    [168 127 183]
#    [155 143 146]
#    [136 149  85]]
#
#   ...,
#   [[212 211 236]
#    [212  57  77]
#    [ 52 135 146]
#    ...,
#    [241 161  67]
#    [ 72   1  42]
#    [ 22 255  92]]
#
#   [[131 117 246]
#    [235   7 157]
#    [100  42  15]
#    ...,
#    [214   6  48]
#    [ 50  36 136]
#    [217  84 183]]
#
#   [[197 124  47]
#    [138 142 126]
#    [ 36 207  55]
#    ...,
#    [168  97  98]
#    [ 54   3 184]
#    [147  40  57]]]
#
#
#  ...,
#  [[[ 88 201 143]
#    [  8 110  41]
#    [ 99  80  41]
#    ...,
#    [112 247 243]
#    [169 150 210]
#    [235 201 165]]
#
#   [[254  63 203]
#    [209 253  26]
#    [111 248 219]
#    ...,
#    [148 103  89]
#    [239 248  44]
#    [ 83  60 120]]
#
#   [[198  70 162]
#    [ 17 112   5]
#    [ 62  48 157]
#    ...,
#    [175  62  89]
#    [162  77 165]
#    [221 237  91]]
#
#   ...,
#   [[175  84 197]
#    [ 41 181 181]
#    [161  70  23]
#    ...,
#    [ 44 226 110]
#    [126  65  90]
#    [ 14 180  18]]
#
#   [[197  96 143]
#    [ 40  42  58]
#    [229  93 222]
#    ...,
#    [112  31 201]
#    [ 17 160 253]
#    [225 250 216]]
#
#   [[ 12  79 185]
#    [211 250   8]
#    [131 166 179]
#    ...,
#    [210  97 255]
#    [ 55  15  67]
#    [142 161 212]]]
#
#
#  [[[246 170 246]
#    [ 56 188 236]
#    [243 238  45]
#    ...,
#    [228 161  80]
#    [ 49 194 223]
#    [213 140  97]]
#
#   [[140  52  24]
#    [108  32  53]
#    [228 134 237]
#    ...,
#    [146 199  88]
#    [106  10  35]
#    [ 90 121 183]]
#
#   [[ 22 193  19]
#    [ 62 130  88]
#    [ 75 222  54]
#    ...,
#    [126  42  50]
#    [224 124   1]
#    [218 184 197]]
#
#   ...,
#   [[185 138 115]
#    [201 141  66]
#    [ 98 173 168]
#    ...,
#    [118  61 221]
#    [250  17 204]
#    [114 150 173]]
#
#   [[ 32 108 155]
#    [225   3 170]
#    [247 204  99]
#    ...,
#    [186 194  90]
#    [ 44 161 190]
#    [115 188 107]]
#
#   [[202  60 203]
#    [  7 185 159]
#    [158  82 149]
#    ...,
#    [153  46 129]
#    [ 62 160 179]
#    [ 16 194  33]]]
#
#
#  [[[  1 198 106]
#    [121 179 166]
#    [211 146 238]
#    ...,
#    [ 22  84 222]
#    [241 211  28]
#    [235 149 170]]
#
#   [[ 47  71 253]
#    [150 140 191]
#    [144 208 253]
#    ...,
#    [136  17 103]
#    [245 207 206]
#    [133  87  77]]
#
#   [[ 25 140  90]
#    [ 83 126 236]
#    [ 96 153  35]
#    ...,
#    [169  78 148]
#    [  1 199  82]
#    [252  96  84]]
#
#   ...,
#   [[174 198 116]
#    [ 62  24  38]
#    [ 42 170  19]
#    ...,
#    [184  26 242]
#    [122  30 109]
#    [  9  37  26]]
#
#   [[132  46 200]
#    [ 89 217 176]
#    [ 33 116  26]
#    ...,
#    [ 42  61 205]
#    [241 211  72]
#    [237 115  39]]
#
#   [[156 179 175]
#    [140 171  94]
#    [217  58 234]
#    ...,
#    [ 92 140 115]
#    [238 224 196]
#    [ 79 159 213]]]]
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    oneHot = np.zeros((len(x), 10))
    for idx, v in enumerate(x):
        oneHot[idx][v] = 1
    return oneHot


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

# %%
def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    print(image_shape)
    return tf.placeholder(tf.float32, shape=[None, image_shape[0], image_shape[1], image_shape[2]], name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=[None, n_classes], name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# (32, 32, 3)
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    #shape = [filter_size, filter_size, num_input_channels, num_filters]
    
    num_input_channels = x_tensor.shape.as_list()[3]
    num_filters = conv_num_outputs
    print("x_tensor shape: {} conv_num_outpus: {} conv_ksize: {}\
            conv_strides: {} pool_ksize: {} pool_strides: {}".format(x_tensor.shape, conv_num_outputs,
                                                                      conv_ksize, conv_strides, pool_ksize, pool_strides)) 
    
    shape = [conv_ksize[0], conv_ksize[1], num_input_channels, num_filters]
    print("shape: ",shape)
    weight = tf.Variable(tf.truncated_normal(shape, mean=0, stddev=0.08))
    bias = tf.Variable(tf.constant(0.05, shape=[num_filters]))
    #bias = tf.Variable(tf.zeros(num_filters))
    conv = tf.nn.conv2d(x_tensor, weight, strides=[1,conv_strides[0], conv_strides[1],1], padding='SAME')
    conv = tf.nn.bias_add(conv, bias)
    conv = tf.nn.relu(conv)
    return tf.nn.max_pool(conv, ksize=[1,pool_ksize[0],pool_ksize[1],1], 
                  strides=[1,pool_strides[0], pool_strides[1], 1],
                  padding='SAME')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# x_tensor shape: (?, 32, 32, 5) conv_num_outpus: 10 conv_ksize: (2, 2)            conv_strides: (4, 4) pool_ksize: (2, 2) pool_strides: (2, 2)
# shape:  [2, 2, 5, 10]
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    #print(x_tensor)
    shape = x_tensor.get_shape()
    num_features = shape[1:4].num_elements()
    layer_flat = tf.reshape(x_tensor, [-1, num_features])
    print("shape: {} num_feautres: {}".format(shape, layer_flat.get_shape().as_list()[1]))
    return layer_flat


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# shape: (?, 10, 30, 6) num_feautres: 1800
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    print(x_tensor.get_shape())
    weights = tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[1], num_outputs], mean=0.0, stddev=0.08))
    bias = tf.Variable(tf.constant(0.05, shape=[num_outputs]))
    #bias = tf.Variable(tf.zeros(num_outputs))
    tf.Variable(tf.zeros(num_outputs))
    fc = tf.matmul(x_tensor, weights) + bias
    return tf.nn.relu(fc)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# (?, 128)
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    weights = tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[1], num_outputs],mean=0.0,stddev=0.5))
    bias = tf.Variable(tf.constant(0.05, shape=[num_outputs]))
    #bias = tf.Variable(tf.zeros(num_outputs))
    out = tf.add(tf.matmul(x_tensor, weights),bias)
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv1 = conv2d_maxpool(x, 128, [5,5], [3,3], [3,3], [2,2])
    conv1 = tf.nn.dropout(conv1, keep_prob)
    conv2 = conv2d_maxpool(conv1, 256, [1,1], [1,1], [1,1], [2,2])
    #conv2 = tf.nn.dropout(conv2, keep_prob)
    #conv3 = conv2d_maxpool(conv2, 128, [5,5], [2,2], [3,3], [2,2])
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    fl1=flatten(conv2)
    print("fl1: ",fl1," : ",fl1.get_shape().as_list()[1])
    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fc1=fully_conn(fl1,fl1.get_shape().as_list()[1])
    #tf.nn.dropout(fc1, keep_prob)
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    out = output(fc1,10)
    return out    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# (32, 32, 3)
# x_tensor shape: (?, 32, 32, 3) conv_num_outpus: 128 conv_ksize: [5, 5]            conv_strides: [3, 3] pool_ksize: [3, 3] pool_strides: [2, 2]
# shape:  [5, 5, 3, 128]
# x_tensor shape: (?, 6, 6, 128) conv_num_outpus: 256 conv_ksize: [1, 1]            conv_strides: [1, 1] pool_ksize: [1, 1] pool_strides: [2, 2]
# shape:  [1, 1, 128, 256]
# shape: (?, 3, 3, 256) num_feautres: 2304
# fl1:  Tensor("Reshape:0", shape=(?, 2304), dtype=float32)  :  2304
# (?, 2304)
# x_tensor shape: (?, 32, 32, 3) conv_num_outpus: 128 conv_ksize: [5, 5]            conv_strides: [3, 3] pool_ksize: [3, 3] pool_strides: [2, 2]
# shape:  [5, 5, 3, 128]
# x_tensor shape: (?, 6, 6, 128) conv_num_outpus: 256 conv_ksize: [1, 1]            conv_strides: [1, 1] pool_ksize: [1, 1] pool_strides: [2, 2]
# shape:  [1, 1, 128, 256]
# shape: (?, 3, 3, 256) num_feautres: 2304
# fl1:  Tensor("Reshape_4:0", shape=(?, 2304), dtype=float32)  :  2304
# (?, 2304)
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={
        x: feature_batch,
        y : label_batch,
        keep_prob : keep_probability
    })


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={
        x : feature_batch,
        y : label_batch,
        keep_prob: 1.0
    })
    validation_accuracy = sess.run(accuracy, feed_dict={
        x: valid_features,
        y: valid_labels,
        keep_prob: 1.0
    })
    print('Loss: {:>10.4f} Accuracy: {:.6f}'.format(loss,validation_accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 90
batch_size = 128
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.0414 Accuracy: 0.333600
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.7599 Accuracy: 0.395800
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.5979 Accuracy: 0.423400
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.4193 Accuracy: 0.436000
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.3684 Accuracy: 0.449600
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.3090 Accuracy: 0.450600
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.1912 Accuracy: 0.448000
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.1183 Accuracy: 0.457200
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.0463 Accuracy: 0.476000
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.0740 Accuracy: 0.472000
# Epoch 11, CIFAR-10 Batch 1:  Loss:     0.9631 Accuracy: 0.477400
# Epoch 12, CIFAR-10 Batch 1:  Loss:     0.8624 Accuracy: 0.487400
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.8496 Accuracy: 0.487800
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.7940 Accuracy: 0.483400
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.7996 Accuracy: 0.475400
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.7634 Accuracy: 0.483600
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.6636 Accuracy: 0.490800
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.5723 Accuracy: 0.506600
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.5174 Accuracy: 0.511200
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.4668 Accuracy: 0.503800
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.4539 Accuracy: 0.509600
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.4705 Accuracy: 0.509400
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.3711 Accuracy: 0.517400
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.2982 Accuracy: 0.506600
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.2631 Accuracy: 0.515400
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.2541 Accuracy: 0.508600
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.2170 Accuracy: 0.509200
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.2258 Accuracy: 0.508000
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.1588 Accuracy: 0.516600
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.1479 Accuracy: 0.505200
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.1172 Accuracy: 0.510000
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.1266 Accuracy: 0.510000
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.0715 Accuracy: 0.506400
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.0944 Accuracy: 0.507800
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.0516 Accuracy: 0.504800
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.0701 Accuracy: 0.513600
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.0663 Accuracy: 0.519600
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.0390 Accuracy: 0.509800
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.0742 Accuracy: 0.510000
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.0377 Accuracy: 0.519000
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.0785 Accuracy: 0.514000
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.0236 Accuracy: 0.509200
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.0329 Accuracy: 0.500600
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.0159 Accuracy: 0.512600
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.0267 Accuracy: 0.504000
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.0124 Accuracy: 0.507400
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.0118 Accuracy: 0.504400
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.0069 Accuracy: 0.505600
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.0133 Accuracy: 0.498600
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.0196 Accuracy: 0.501200
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.0060 Accuracy: 0.512200
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.0086 Accuracy: 0.516600
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.0086 Accuracy: 0.510000
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.0176 Accuracy: 0.506800
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.0061 Accuracy: 0.503400
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.0032 Accuracy: 0.504400
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.0181 Accuracy: 0.493800
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.0060 Accuracy: 0.513200
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.0061 Accuracy: 0.507600
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.0026 Accuracy: 0.503800
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.0058 Accuracy: 0.503800
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.0040 Accuracy: 0.500000
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.0067 Accuracy: 0.507000
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.0033 Accuracy: 0.505400
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.0039 Accuracy: 0.508000
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.0027 Accuracy: 0.482800
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.0037 Accuracy: 0.503400
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.0051 Accuracy: 0.500000
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.0035 Accuracy: 0.505200
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.0113 Accuracy: 0.505000
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.0089 Accuracy: 0.500800
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.0162 Accuracy: 0.511200
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.0026 Accuracy: 0.505000
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.0051 Accuracy: 0.505800
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.0054 Accuracy: 0.502400
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.0016 Accuracy: 0.515200
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.0010 Accuracy: 0.511600
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.0014 Accuracy: 0.509200
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.0028 Accuracy: 0.513600
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.0012 Accuracy: 0.500400
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.0021 Accuracy: 0.498000
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.0020 Accuracy: 0.503200
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.0026 Accuracy: 0.489000
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.0010 Accuracy: 0.506600
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.0009 Accuracy: 0.504400
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.0002 Accuracy: 0.511800
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.0004 Accuracy: 0.517600
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.0008 Accuracy: 0.502200
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.0014 Accuracy: 0.495200
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.0004 Accuracy: 0.507000

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.0476 Accuracy: 0.324000
# Epoch  1, CIFAR-10 Batch 2:  Loss:     1.4898 Accuracy: 0.398600
# Epoch  1, CIFAR-10 Batch 3:  Loss:     1.6121 Accuracy: 0.410200
# Epoch  1, CIFAR-10 Batch 4:  Loss:     1.5187 Accuracy: 0.443800
# Epoch  1, CIFAR-10 Batch 5:  Loss:     1.6986 Accuracy: 0.425200
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.5515 Accuracy: 0.453800
# Epoch  2, CIFAR-10 Batch 2:  Loss:     1.2492 Accuracy: 0.451400
# Epoch  2, CIFAR-10 Batch 3:  Loss:     1.3224 Accuracy: 0.460600
# Epoch  2, CIFAR-10 Batch 4:  Loss:     1.3889 Accuracy: 0.471000
# Epoch  2, CIFAR-10 Batch 5:  Loss:     1.5133 Accuracy: 0.460000
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.4628 Accuracy: 0.478800
# Epoch  3, CIFAR-10 Batch 2:  Loss:     1.2502 Accuracy: 0.470000
# Epoch  3, CIFAR-10 Batch 3:  Loss:     1.2170 Accuracy: 0.472200
# Epoch  3, CIFAR-10 Batch 4:  Loss:     1.4057 Accuracy: 0.479600
# Epoch  3, CIFAR-10 Batch 5:  Loss:     1.4038 Accuracy: 0.473200
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.3754 Accuracy: 0.487800
# Epoch  4, CIFAR-10 Batch 2:  Loss:     1.1092 Accuracy: 0.489800
# Epoch  4, CIFAR-10 Batch 3:  Loss:     1.1415 Accuracy: 0.500600
# Epoch  4, CIFAR-10 Batch 4:  Loss:     1.3690 Accuracy: 0.504200
# Epoch  4, CIFAR-10 Batch 5:  Loss:     1.2870 Accuracy: 0.512400
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.2824 Accuracy: 0.513000
# Epoch  5, CIFAR-10 Batch 2:  Loss:     1.0853 Accuracy: 0.516600
# Epoch  5, CIFAR-10 Batch 3:  Loss:     0.9836 Accuracy: 0.518600
# Epoch  5, CIFAR-10 Batch 4:  Loss:     1.2341 Accuracy: 0.525600
# Epoch  5, CIFAR-10 Batch 5:  Loss:     1.2811 Accuracy: 0.515800
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.1427 Accuracy: 0.528000
# Epoch  6, CIFAR-10 Batch 2:  Loss:     1.0535 Accuracy: 0.532800
# Epoch  6, CIFAR-10 Batch 3:  Loss:     0.8460 Accuracy: 0.535200
# Epoch  6, CIFAR-10 Batch 4:  Loss:     1.1532 Accuracy: 0.536600
# Epoch  6, CIFAR-10 Batch 5:  Loss:     1.0799 Accuracy: 0.541400
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.0308 Accuracy: 0.540200
# Epoch  7, CIFAR-10 Batch 2:  Loss:     0.8234 Accuracy: 0.557800
# Epoch  7, CIFAR-10 Batch 3:  Loss:     0.7511 Accuracy: 0.545800
# Epoch  7, CIFAR-10 Batch 4:  Loss:     1.0489 Accuracy: 0.557600
# Epoch  7, CIFAR-10 Batch 5:  Loss:     1.1236 Accuracy: 0.541400
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.0414 Accuracy: 0.560800
# Epoch  8, CIFAR-10 Batch 2:  Loss:     0.7871 Accuracy: 0.564000
# Epoch  8, CIFAR-10 Batch 3:  Loss:     0.6796 Accuracy: 0.561600
# Epoch  8, CIFAR-10 Batch 4:  Loss:     1.0252 Accuracy: 0.561800
# Epoch  8, CIFAR-10 Batch 5:  Loss:     0.9505 Accuracy: 0.567400
# Epoch  9, CIFAR-10 Batch 1:  Loss:     0.9458 Accuracy: 0.571600
# Epoch  9, CIFAR-10 Batch 2:  Loss:     0.6499 Accuracy: 0.574400
# Epoch  9, CIFAR-10 Batch 3:  Loss:     0.6080 Accuracy: 0.573000
# Epoch  9, CIFAR-10 Batch 4:  Loss:     0.9350 Accuracy: 0.580200
# Epoch  9, CIFAR-10 Batch 5:  Loss:     0.8091 Accuracy: 0.584400
# Epoch 10, CIFAR-10 Batch 1:  Loss:     0.9055 Accuracy: 0.585400
# Epoch 10, CIFAR-10 Batch 2:  Loss:     0.6260 Accuracy: 0.588600
# Epoch 10, CIFAR-10 Batch 3:  Loss:     0.5874 Accuracy: 0.578000
# Epoch 10, CIFAR-10 Batch 4:  Loss:     0.8074 Accuracy: 0.593000
# Epoch 10, CIFAR-10 Batch 5:  Loss:     0.7441 Accuracy: 0.581800
# Epoch 11, CIFAR-10 Batch 1:  Loss:     0.7809 Accuracy: 0.591800
# Epoch 11, CIFAR-10 Batch 2:  Loss:     0.6041 Accuracy: 0.593200
# Epoch 11, CIFAR-10 Batch 3:  Loss:     0.5541 Accuracy: 0.585800
# Epoch 11, CIFAR-10 Batch 4:  Loss:     0.6705 Accuracy: 0.595000
# Epoch 11, CIFAR-10 Batch 5:  Loss:     0.6403 Accuracy: 0.600000
# Epoch 12, CIFAR-10 Batch 1:  Loss:     0.6837 Accuracy: 0.607800
# Epoch 12, CIFAR-10 Batch 2:  Loss:     0.5169 Accuracy: 0.590600
# Epoch 12, CIFAR-10 Batch 3:  Loss:     0.4916 Accuracy: 0.582600
# Epoch 12, CIFAR-10 Batch 4:  Loss:     0.6309 Accuracy: 0.600000
# Epoch 12, CIFAR-10 Batch 5:  Loss:     0.5020 Accuracy: 0.610800
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.6474 Accuracy: 0.606600
# Epoch 13, CIFAR-10 Batch 2:  Loss:     0.4410 Accuracy: 0.601800
# Epoch 13, CIFAR-10 Batch 3:  Loss:     0.3652 Accuracy: 0.590600
# Epoch 13, CIFAR-10 Batch 4:  Loss:     0.5377 Accuracy: 0.607000
# Epoch 13, CIFAR-10 Batch 5:  Loss:     0.4860 Accuracy: 0.598400
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.6145 Accuracy: 0.594000
# Epoch 14, CIFAR-10 Batch 2:  Loss:     0.3428 Accuracy: 0.599400
# Epoch 14, CIFAR-10 Batch 3:  Loss:     0.3432 Accuracy: 0.587400
# Epoch 14, CIFAR-10 Batch 4:  Loss:     0.4533 Accuracy: 0.615400
# Epoch 14, CIFAR-10 Batch 5:  Loss:     0.3718 Accuracy: 0.601400
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.4981 Accuracy: 0.603400
# Epoch 15, CIFAR-10 Batch 2:  Loss:     0.3392 Accuracy: 0.611400
# Epoch 15, CIFAR-10 Batch 3:  Loss:     0.2770 Accuracy: 0.593200
# Epoch 15, CIFAR-10 Batch 4:  Loss:     0.3692 Accuracy: 0.605200
# Epoch 15, CIFAR-10 Batch 5:  Loss:     0.3013 Accuracy: 0.619600
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.4627 Accuracy: 0.614800
# Epoch 16, CIFAR-10 Batch 2:  Loss:     0.2960 Accuracy: 0.604000
# Epoch 16, CIFAR-10 Batch 3:  Loss:     0.2124 Accuracy: 0.603200
# Epoch 16, CIFAR-10 Batch 4:  Loss:     0.2739 Accuracy: 0.623000
# Epoch 16, CIFAR-10 Batch 5:  Loss:     0.2305 Accuracy: 0.619600
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.3896 Accuracy: 0.621000
# Epoch 17, CIFAR-10 Batch 2:  Loss:     0.2063 Accuracy: 0.615000
# Epoch 17, CIFAR-10 Batch 3:  Loss:     0.2258 Accuracy: 0.585600
# Epoch 17, CIFAR-10 Batch 4:  Loss:     0.1768 Accuracy: 0.619400
# Epoch 17, CIFAR-10 Batch 5:  Loss:     0.2323 Accuracy: 0.599200
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.2679 Accuracy: 0.621600
# Epoch 18, CIFAR-10 Batch 2:  Loss:     0.1867 Accuracy: 0.597400
# Epoch 18, CIFAR-10 Batch 3:  Loss:     0.1610 Accuracy: 0.600200
# Epoch 18, CIFAR-10 Batch 4:  Loss:     0.1546 Accuracy: 0.618800
# Epoch 18, CIFAR-10 Batch 5:  Loss:     0.1771 Accuracy: 0.624000
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.2779 Accuracy: 0.616600
# Epoch 19, CIFAR-10 Batch 2:  Loss:     0.1238 Accuracy: 0.614200
# Epoch 19, CIFAR-10 Batch 3:  Loss:     0.1452 Accuracy: 0.609400
# Epoch 19, CIFAR-10 Batch 4:  Loss:     0.1519 Accuracy: 0.613600
# Epoch 19, CIFAR-10 Batch 5:  Loss:     0.1262 Accuracy: 0.615000
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.2501 Accuracy: 0.611200
# Epoch 20, CIFAR-10 Batch 2:  Loss:     0.1288 Accuracy: 0.617000
# Epoch 20, CIFAR-10 Batch 3:  Loss:     0.0746 Accuracy: 0.599600
# Epoch 20, CIFAR-10 Batch 4:  Loss:     0.1224 Accuracy: 0.609400
# Epoch 20, CIFAR-10 Batch 5:  Loss:     0.1211 Accuracy: 0.594600
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.1546 Accuracy: 0.619600
# Epoch 21, CIFAR-10 Batch 2:  Loss:     0.0964 Accuracy: 0.613200
# Epoch 21, CIFAR-10 Batch 3:  Loss:     0.0831 Accuracy: 0.606800
# Epoch 21, CIFAR-10 Batch 4:  Loss:     0.0803 Accuracy: 0.612400
# Epoch 21, CIFAR-10 Batch 5:  Loss:     0.0892 Accuracy: 0.616200
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.1102 Accuracy: 0.618600
# Epoch 22, CIFAR-10 Batch 2:  Loss:     0.0627 Accuracy: 0.609000
# Epoch 22, CIFAR-10 Batch 3:  Loss:     0.0503 Accuracy: 0.599400
# Epoch 22, CIFAR-10 Batch 4:  Loss:     0.0926 Accuracy: 0.620800
# Epoch 22, CIFAR-10 Batch 5:  Loss:     0.0787 Accuracy: 0.616200
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.1187 Accuracy: 0.620800
# Epoch 23, CIFAR-10 Batch 2:  Loss:     0.0483 Accuracy: 0.607000
# Epoch 23, CIFAR-10 Batch 3:  Loss:     0.0572 Accuracy: 0.611200
# Epoch 23, CIFAR-10 Batch 4:  Loss:     0.0628 Accuracy: 0.615800
# Epoch 23, CIFAR-10 Batch 5:  Loss:     0.0774 Accuracy: 0.610000
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.1005 Accuracy: 0.615800
# Epoch 24, CIFAR-10 Batch 2:  Loss:     0.0365 Accuracy: 0.610800
# Epoch 24, CIFAR-10 Batch 3:  Loss:     0.0451 Accuracy: 0.609000
# Epoch 24, CIFAR-10 Batch 4:  Loss:     0.0548 Accuracy: 0.610800
# Epoch 24, CIFAR-10 Batch 5:  Loss:     0.0485 Accuracy: 0.603600
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.0569 Accuracy: 0.612800
# Epoch 25, CIFAR-10 Batch 2:  Loss:     0.0219 Accuracy: 0.607000
# Epoch 25, CIFAR-10 Batch 3:  Loss:     0.0176 Accuracy: 0.612200
# Epoch 25, CIFAR-10 Batch 4:  Loss:     0.1024 Accuracy: 0.612600
# Epoch 25, CIFAR-10 Batch 5:  Loss:     0.0663 Accuracy: 0.606000
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.0553 Accuracy: 0.612800
# Epoch 26, CIFAR-10 Batch 2:  Loss:     0.0245 Accuracy: 0.609200
# Epoch 26, CIFAR-10 Batch 3:  Loss:     0.0297 Accuracy: 0.601200
# Epoch 26, CIFAR-10 Batch 4:  Loss:     0.0524 Accuracy: 0.615400
# Epoch 26, CIFAR-10 Batch 5:  Loss:     0.1022 Accuracy: 0.615600
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.0667 Accuracy: 0.605600
# Epoch 27, CIFAR-10 Batch 2:  Loss:     0.0358 Accuracy: 0.616400
# Epoch 27, CIFAR-10 Batch 3:  Loss:     0.0234 Accuracy: 0.606400
# Epoch 27, CIFAR-10 Batch 4:  Loss:     0.0319 Accuracy: 0.616800
# Epoch 27, CIFAR-10 Batch 5:  Loss:     0.0363 Accuracy: 0.615000
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.0793 Accuracy: 0.613600
# Epoch 28, CIFAR-10 Batch 2:  Loss:     0.0204 Accuracy: 0.611800
# Epoch 28, CIFAR-10 Batch 3:  Loss:     0.0231 Accuracy: 0.616400
# Epoch 28, CIFAR-10 Batch 4:  Loss:     0.0498 Accuracy: 0.609600
# Epoch 28, CIFAR-10 Batch 5:  Loss:     0.0529 Accuracy: 0.610800
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.0931 Accuracy: 0.615000
# Epoch 29, CIFAR-10 Batch 2:  Loss:     0.0255 Accuracy: 0.606200
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.0121 Accuracy: 0.615400
# Epoch 29, CIFAR-10 Batch 4:  Loss:     0.0326 Accuracy: 0.599800
# Epoch 29, CIFAR-10 Batch 5:  Loss:     0.0286 Accuracy: 0.607400
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.0429 Accuracy: 0.609800
# Epoch 30, CIFAR-10 Batch 2:  Loss:     0.0125 Accuracy: 0.607600
# Epoch 30, CIFAR-10 Batch 3:  Loss:     0.0238 Accuracy: 0.612600
# Epoch 30, CIFAR-10 Batch 4:  Loss:     0.0223 Accuracy: 0.617400
# Epoch 30, CIFAR-10 Batch 5:  Loss:     0.0304 Accuracy: 0.612400
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.0368 Accuracy: 0.608200
# Epoch 31, CIFAR-10 Batch 2:  Loss:     0.0108 Accuracy: 0.606400
# Epoch 31, CIFAR-10 Batch 3:  Loss:     0.0110 Accuracy: 0.609600
# Epoch 31, CIFAR-10 Batch 4:  Loss:     0.0273 Accuracy: 0.607400
# Epoch 31, CIFAR-10 Batch 5:  Loss:     0.0628 Accuracy: 0.610600
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.0287 Accuracy: 0.607600
# Epoch 32, CIFAR-10 Batch 2:  Loss:     0.0174 Accuracy: 0.613200
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.0093 Accuracy: 0.621200
# Epoch 32, CIFAR-10 Batch 4:  Loss:     0.0216 Accuracy: 0.610200
# Epoch 32, CIFAR-10 Batch 5:  Loss:     0.0314 Accuracy: 0.602200
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.0228 Accuracy: 0.610600
# Epoch 33, CIFAR-10 Batch 2:  Loss:     0.0086 Accuracy: 0.603800
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.0072 Accuracy: 0.612400
# Epoch 33, CIFAR-10 Batch 4:  Loss:     0.0319 Accuracy: 0.603800
# Epoch 33, CIFAR-10 Batch 5:  Loss:     0.0361 Accuracy: 0.604000
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.0143 Accuracy: 0.607400
# Epoch 34, CIFAR-10 Batch 2:  Loss:     0.0107 Accuracy: 0.608000
# Epoch 34, CIFAR-10 Batch 3:  Loss:     0.0153 Accuracy: 0.614600
# Epoch 34, CIFAR-10 Batch 4:  Loss:     0.0096 Accuracy: 0.606600
# Epoch 34, CIFAR-10 Batch 5:  Loss:     0.0229 Accuracy: 0.582000
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.0064 Accuracy: 0.609600
# Epoch 35, CIFAR-10 Batch 2:  Loss:     0.0132 Accuracy: 0.603800
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.0046 Accuracy: 0.605400
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.0116 Accuracy: 0.608800
# Epoch 35, CIFAR-10 Batch 5:  Loss:     0.0187 Accuracy: 0.598600
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.0066 Accuracy: 0.608400
# Epoch 36, CIFAR-10 Batch 2:  Loss:     0.0158 Accuracy: 0.604600
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.0127 Accuracy: 0.613200
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.0093 Accuracy: 0.602000
# Epoch 36, CIFAR-10 Batch 5:  Loss:     0.0119 Accuracy: 0.607600
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.0169 Accuracy: 0.598800
# Epoch 37, CIFAR-10 Batch 2:  Loss:     0.0179 Accuracy: 0.602800
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.0072 Accuracy: 0.603800
# Epoch 37, CIFAR-10 Batch 4:  Loss:     0.0090 Accuracy: 0.615600
# Epoch 37, CIFAR-10 Batch 5:  Loss:     0.0220 Accuracy: 0.607400
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.0178 Accuracy: 0.605800
# Epoch 38, CIFAR-10 Batch 2:  Loss:     0.0074 Accuracy: 0.603000
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.0038 Accuracy: 0.609400
# Epoch 38, CIFAR-10 Batch 4:  Loss:     0.0114 Accuracy: 0.612200
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.0161 Accuracy: 0.584200
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.0075 Accuracy: 0.613200
# Epoch 39, CIFAR-10 Batch 2:  Loss:     0.0192 Accuracy: 0.606600
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.0026 Accuracy: 0.612800
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.0079 Accuracy: 0.612400
# Epoch 39, CIFAR-10 Batch 5:  Loss:     0.0195 Accuracy: 0.612400
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.0242 Accuracy: 0.607000
# Epoch 40, CIFAR-10 Batch 2:  Loss:     0.0111 Accuracy: 0.606400
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.0084 Accuracy: 0.598200
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.0245 Accuracy: 0.612000
# Epoch 40, CIFAR-10 Batch 5:  Loss:     0.0133 Accuracy: 0.606800
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.0026 Accuracy: 0.609600
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.0043 Accuracy: 0.608400
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.0066 Accuracy: 0.602200
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.0057 Accuracy: 0.610000
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.0048 Accuracy: 0.609400
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.0096 Accuracy: 0.594200
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.0065 Accuracy: 0.605800
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.0051 Accuracy: 0.608600
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.0071 Accuracy: 0.608800
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.0071 Accuracy: 0.603600
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.0015 Accuracy: 0.608800
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.0085 Accuracy: 0.602400
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.0040 Accuracy: 0.601400
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.0103 Accuracy: 0.605600
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.0167 Accuracy: 0.606600
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.0031 Accuracy: 0.598200
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.0144 Accuracy: 0.600600
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.0045 Accuracy: 0.598000
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.0051 Accuracy: 0.597800
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.0389 Accuracy: 0.608400
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.0031 Accuracy: 0.604600
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.0027 Accuracy: 0.601000
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.0023 Accuracy: 0.610800
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.0122 Accuracy: 0.601400
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.0217 Accuracy: 0.608000
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.0127 Accuracy: 0.605600
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.0077 Accuracy: 0.600800
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.0022 Accuracy: 0.603200
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.0119 Accuracy: 0.599400
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.0059 Accuracy: 0.607000
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.0028 Accuracy: 0.606000
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.0040 Accuracy: 0.594800
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.0036 Accuracy: 0.603200
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.0031 Accuracy: 0.611800
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.0186 Accuracy: 0.604000
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.0010 Accuracy: 0.611600
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.0018 Accuracy: 0.610000
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.0033 Accuracy: 0.599600
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.0056 Accuracy: 0.602600
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.0140 Accuracy: 0.602400
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.0016 Accuracy: 0.604000
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.0032 Accuracy: 0.603200
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.0021 Accuracy: 0.605200
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.0060 Accuracy: 0.603000
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.0169 Accuracy: 0.602800
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.0021 Accuracy: 0.589400
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.0180 Accuracy: 0.610800
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.0009 Accuracy: 0.607400
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.0064 Accuracy: 0.612200
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.0064 Accuracy: 0.612200
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.0020 Accuracy: 0.603400
# Epoch 51, CIFAR-10 Batch 2:  Loss:     0.0012 Accuracy: 0.605800
# Epoch 51, CIFAR-10 Batch 3:  Loss:     0.0018 Accuracy: 0.602600
# Epoch 51, CIFAR-10 Batch 4:  Loss:     0.0092 Accuracy: 0.612200
# Epoch 51, CIFAR-10 Batch 5:  Loss:     0.0046 Accuracy: 0.605400
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.0032 Accuracy: 0.603600
# Epoch 52, CIFAR-10 Batch 2:  Loss:     0.0022 Accuracy: 0.610000
# Epoch 52, CIFAR-10 Batch 3:  Loss:     0.0028 Accuracy: 0.598000
# Epoch 52, CIFAR-10 Batch 4:  Loss:     0.0036 Accuracy: 0.611600
# Epoch 52, CIFAR-10 Batch 5:  Loss:     0.0135 Accuracy: 0.598600
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.0006 Accuracy: 0.604000
# Epoch 53, CIFAR-10 Batch 2:  Loss:     0.0016 Accuracy: 0.598000
# Epoch 53, CIFAR-10 Batch 3:  Loss:     0.0016 Accuracy: 0.598200
# Epoch 53, CIFAR-10 Batch 4:  Loss:     0.0070 Accuracy: 0.596200
# Epoch 53, CIFAR-10 Batch 5:  Loss:     0.0129 Accuracy: 0.608000
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.0029 Accuracy: 0.604800
# Epoch 54, CIFAR-10 Batch 2:  Loss:     0.0011 Accuracy: 0.599200
# Epoch 54, CIFAR-10 Batch 3:  Loss:     0.0012 Accuracy: 0.606600
# Epoch 54, CIFAR-10 Batch 4:  Loss:     0.0065 Accuracy: 0.606400
# Epoch 54, CIFAR-10 Batch 5:  Loss:     0.0046 Accuracy: 0.600200
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.0015 Accuracy: 0.612800
# Epoch 55, CIFAR-10 Batch 2:  Loss:     0.0014 Accuracy: 0.600600
# Epoch 55, CIFAR-10 Batch 3:  Loss:     0.0024 Accuracy: 0.606800
# Epoch 55, CIFAR-10 Batch 4:  Loss:     0.0078 Accuracy: 0.609600
# Epoch 55, CIFAR-10 Batch 5:  Loss:     0.0079 Accuracy: 0.610400
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.0012 Accuracy: 0.607400
# Epoch 56, CIFAR-10 Batch 2:  Loss:     0.0007 Accuracy: 0.610600
# Epoch 56, CIFAR-10 Batch 3:  Loss:     0.0008 Accuracy: 0.597800
# Epoch 56, CIFAR-10 Batch 4:  Loss:     0.0081 Accuracy: 0.602200
# Epoch 56, CIFAR-10 Batch 5:  Loss:     0.0014 Accuracy: 0.609400
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.0021 Accuracy: 0.602400
# Epoch 57, CIFAR-10 Batch 2:  Loss:     0.0004 Accuracy: 0.600000
# Epoch 57, CIFAR-10 Batch 3:  Loss:     0.0012 Accuracy: 0.598000
# Epoch 57, CIFAR-10 Batch 4:  Loss:     0.0065 Accuracy: 0.604000
# Epoch 57, CIFAR-10 Batch 5:  Loss:     0.0014 Accuracy: 0.614400
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.0092 Accuracy: 0.617000
# Epoch 58, CIFAR-10 Batch 2:  Loss:     0.0007 Accuracy: 0.614400
# Epoch 58, CIFAR-10 Batch 3:  Loss:     0.0010 Accuracy: 0.616400
# Epoch 58, CIFAR-10 Batch 4:  Loss:     0.0033 Accuracy: 0.604200
# Epoch 58, CIFAR-10 Batch 5:  Loss:     0.0033 Accuracy: 0.607400
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.0027 Accuracy: 0.609200
# Epoch 59, CIFAR-10 Batch 2:  Loss:     0.0021 Accuracy: 0.601200
# Epoch 59, CIFAR-10 Batch 3:  Loss:     0.0004 Accuracy: 0.603800
# Epoch 59, CIFAR-10 Batch 4:  Loss:     0.0022 Accuracy: 0.605400
# Epoch 59, CIFAR-10 Batch 5:  Loss:     0.0016 Accuracy: 0.606600
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.0036 Accuracy: 0.594000
# Epoch 60, CIFAR-10 Batch 2:  Loss:     0.0005 Accuracy: 0.598400
# Epoch 60, CIFAR-10 Batch 3:  Loss:     0.0029 Accuracy: 0.598800
# Epoch 60, CIFAR-10 Batch 4:  Loss:     0.0066 Accuracy: 0.603400
# Epoch 60, CIFAR-10 Batch 5:  Loss:     0.0006 Accuracy: 0.609000
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.0046 Accuracy: 0.611400
# Epoch 61, CIFAR-10 Batch 2:  Loss:     0.0075 Accuracy: 0.591800
# Epoch 61, CIFAR-10 Batch 3:  Loss:     0.0017 Accuracy: 0.602000
# Epoch 61, CIFAR-10 Batch 4:  Loss:     0.0020 Accuracy: 0.602600
# Epoch 61, CIFAR-10 Batch 5:  Loss:     0.0028 Accuracy: 0.616400
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.0071 Accuracy: 0.598400
# Epoch 62, CIFAR-10 Batch 2:  Loss:     0.0006 Accuracy: 0.601000
# Epoch 62, CIFAR-10 Batch 3:  Loss:     0.0011 Accuracy: 0.598800
# Epoch 62, CIFAR-10 Batch 4:  Loss:     0.0083 Accuracy: 0.609200
# Epoch 62, CIFAR-10 Batch 5:  Loss:     0.0050 Accuracy: 0.607800
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.0128 Accuracy: 0.604000
# Epoch 63, CIFAR-10 Batch 2:  Loss:     0.0027 Accuracy: 0.605400
# Epoch 63, CIFAR-10 Batch 3:  Loss:     0.0042 Accuracy: 0.602200
# Epoch 63, CIFAR-10 Batch 4:  Loss:     0.0238 Accuracy: 0.610600
# Epoch 63, CIFAR-10 Batch 5:  Loss:     0.0068 Accuracy: 0.605600
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.0010 Accuracy: 0.603200
# Epoch 64, CIFAR-10 Batch 2:  Loss:     0.0026 Accuracy: 0.603000
# Epoch 64, CIFAR-10 Batch 3:  Loss:     0.0011 Accuracy: 0.595200
# Epoch 64, CIFAR-10 Batch 4:  Loss:     0.0023 Accuracy: 0.600400
# Epoch 64, CIFAR-10 Batch 5:  Loss:     0.0006 Accuracy: 0.604800
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.0041 Accuracy: 0.607200
# Epoch 65, CIFAR-10 Batch 2:  Loss:     0.0043 Accuracy: 0.592600
# Epoch 65, CIFAR-10 Batch 3:  Loss:     0.0007 Accuracy: 0.603000
# Epoch 65, CIFAR-10 Batch 4:  Loss:     0.0013 Accuracy: 0.602800
# Epoch 65, CIFAR-10 Batch 5:  Loss:     0.0025 Accuracy: 0.603600
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.0117 Accuracy: 0.611400
# Epoch 66, CIFAR-10 Batch 2:  Loss:     0.0003 Accuracy: 0.603000
# Epoch 66, CIFAR-10 Batch 3:  Loss:     0.0003 Accuracy: 0.607600
# Epoch 66, CIFAR-10 Batch 4:  Loss:     0.0083 Accuracy: 0.600400
# Epoch 66, CIFAR-10 Batch 5:  Loss:     0.0006 Accuracy: 0.602200
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.0004 Accuracy: 0.602400
# Epoch 67, CIFAR-10 Batch 2:  Loss:     0.0001 Accuracy: 0.607400
# Epoch 67, CIFAR-10 Batch 3:  Loss:     0.0005 Accuracy: 0.596000
# Epoch 67, CIFAR-10 Batch 4:  Loss:     0.0007 Accuracy: 0.611800
# Epoch 67, CIFAR-10 Batch 5:  Loss:     0.0012 Accuracy: 0.610600
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.0017 Accuracy: 0.606400
# Epoch 68, CIFAR-10 Batch 2:  Loss:     0.0004 Accuracy: 0.603200
# Epoch 68, CIFAR-10 Batch 3:  Loss:     0.0015 Accuracy: 0.599000
# Epoch 68, CIFAR-10 Batch 4:  Loss:     0.0032 Accuracy: 0.597200
# Epoch 68, CIFAR-10 Batch 5:  Loss:     0.0008 Accuracy: 0.604400
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.0014 Accuracy: 0.600800
# Epoch 69, CIFAR-10 Batch 2:  Loss:     0.0006 Accuracy: 0.601600
# Epoch 69, CIFAR-10 Batch 3:  Loss:     0.0002 Accuracy: 0.605600
# Epoch 69, CIFAR-10 Batch 4:  Loss:     0.0088 Accuracy: 0.604800
# Epoch 69, CIFAR-10 Batch 5:  Loss:     0.0005 Accuracy: 0.596600
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.0008 Accuracy: 0.599400
# Epoch 70, CIFAR-10 Batch 2:  Loss:     0.0002 Accuracy: 0.607600
# Epoch 70, CIFAR-10 Batch 3:  Loss:     0.0005 Accuracy: 0.600800
# Epoch 70, CIFAR-10 Batch 4:  Loss:     0.0013 Accuracy: 0.596400
# Epoch 70, CIFAR-10 Batch 5:  Loss:     0.0017 Accuracy: 0.595000
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.0005 Accuracy: 0.607400
# Epoch 71, CIFAR-10 Batch 2:  Loss:     0.0013 Accuracy: 0.600600
# Epoch 71, CIFAR-10 Batch 3:  Loss:     0.0003 Accuracy: 0.602600
# Epoch 71, CIFAR-10 Batch 4:  Loss:     0.0013 Accuracy: 0.606200
# Epoch 71, CIFAR-10 Batch 5:  Loss:     0.0008 Accuracy: 0.609000
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.0031 Accuracy: 0.607000
# Epoch 72, CIFAR-10 Batch 2:  Loss:     0.0048 Accuracy: 0.598000
# Epoch 72, CIFAR-10 Batch 3:  Loss:     0.0004 Accuracy: 0.605000
# Epoch 72, CIFAR-10 Batch 4:  Loss:     0.0008 Accuracy: 0.601200
# Epoch 72, CIFAR-10 Batch 5:  Loss:     0.0040 Accuracy: 0.593200
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.0016 Accuracy: 0.600800
# Epoch 73, CIFAR-10 Batch 2:  Loss:     0.0001 Accuracy: 0.600400
# Epoch 73, CIFAR-10 Batch 3:  Loss:     0.0005 Accuracy: 0.602200
# Epoch 73, CIFAR-10 Batch 4:  Loss:     0.0022 Accuracy: 0.610000
# Epoch 73, CIFAR-10 Batch 5:  Loss:     0.0011 Accuracy: 0.600000
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.0005 Accuracy: 0.603800
# Epoch 74, CIFAR-10 Batch 2:  Loss:     0.0003 Accuracy: 0.595800
# Epoch 74, CIFAR-10 Batch 3:  Loss:     0.0002 Accuracy: 0.606800
# Epoch 74, CIFAR-10 Batch 4:  Loss:     0.0178 Accuracy: 0.591800
# Epoch 74, CIFAR-10 Batch 5:  Loss:     0.0028 Accuracy: 0.598000
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.0049 Accuracy: 0.606800
# Epoch 75, CIFAR-10 Batch 2:  Loss:     0.0008 Accuracy: 0.602000
# Epoch 75, CIFAR-10 Batch 3:  Loss:     0.0001 Accuracy: 0.596000
# Epoch 75, CIFAR-10 Batch 4:  Loss:     0.0009 Accuracy: 0.606200
# Epoch 75, CIFAR-10 Batch 5:  Loss:     0.0041 Accuracy: 0.610800
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.0012 Accuracy: 0.605000
# Epoch 76, CIFAR-10 Batch 2:  Loss:     0.0017 Accuracy: 0.605000
# Epoch 76, CIFAR-10 Batch 3:  Loss:     0.0002 Accuracy: 0.599800
# Epoch 76, CIFAR-10 Batch 4:  Loss:     0.0021 Accuracy: 0.600400
# Epoch 76, CIFAR-10 Batch 5:  Loss:     0.0013 Accuracy: 0.600200
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.0033 Accuracy: 0.597800
# Epoch 77, CIFAR-10 Batch 2:  Loss:     0.0001 Accuracy: 0.608400
# Epoch 77, CIFAR-10 Batch 3:  Loss:     0.0006 Accuracy: 0.598400
# Epoch 77, CIFAR-10 Batch 4:  Loss:     0.0222 Accuracy: 0.600000
# Epoch 77, CIFAR-10 Batch 5:  Loss:     0.0008 Accuracy: 0.611200
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.0026 Accuracy: 0.610200
# Epoch 78, CIFAR-10 Batch 2:  Loss:     0.0005 Accuracy: 0.599400
# Epoch 78, CIFAR-10 Batch 3:  Loss:     0.0003 Accuracy: 0.607200
# Epoch 78, CIFAR-10 Batch 4:  Loss:     0.0260 Accuracy: 0.603600
# Epoch 78, CIFAR-10 Batch 5:  Loss:     0.0005 Accuracy: 0.606400
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.0137 Accuracy: 0.604400
# Epoch 79, CIFAR-10 Batch 2:  Loss:     0.0001 Accuracy: 0.612600
# Epoch 79, CIFAR-10 Batch 3:  Loss:     0.0001 Accuracy: 0.597800
# Epoch 79, CIFAR-10 Batch 4:  Loss:     0.0023 Accuracy: 0.595400
# Epoch 79, CIFAR-10 Batch 5:  Loss:     0.0133 Accuracy: 0.597800
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.0064 Accuracy: 0.605000
# Epoch 80, CIFAR-10 Batch 2:  Loss:     0.0002 Accuracy: 0.604200
# Epoch 80, CIFAR-10 Batch 3:  Loss:     0.0002 Accuracy: 0.604600
# Epoch 80, CIFAR-10 Batch 4:  Loss:     0.0096 Accuracy: 0.604200
# Epoch 80, CIFAR-10 Batch 5:  Loss:     0.0030 Accuracy: 0.605400
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.0030 Accuracy: 0.604000
# Epoch 81, CIFAR-10 Batch 2:  Loss:     0.0002 Accuracy: 0.597000
# Epoch 81, CIFAR-10 Batch 3:  Loss:     0.0003 Accuracy: 0.598600
# Epoch 81, CIFAR-10 Batch 4:  Loss:     0.0004 Accuracy: 0.606000
# Epoch 81, CIFAR-10 Batch 5:  Loss:     0.0008 Accuracy: 0.602400
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.0085 Accuracy: 0.604600
# Epoch 82, CIFAR-10 Batch 2:  Loss:     0.0034 Accuracy: 0.600200
# Epoch 82, CIFAR-10 Batch 3:  Loss:     0.0001 Accuracy: 0.593400
# Epoch 82, CIFAR-10 Batch 4:  Loss:     0.0086 Accuracy: 0.605600
# Epoch 82, CIFAR-10 Batch 5:  Loss:     0.0019 Accuracy: 0.606600
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.0033 Accuracy: 0.602400
# Epoch 83, CIFAR-10 Batch 2:  Loss:     0.0009 Accuracy: 0.601800
# Epoch 83, CIFAR-10 Batch 3:  Loss:     0.0004 Accuracy: 0.604000
# Epoch 83, CIFAR-10 Batch 4:  Loss:     0.0076 Accuracy: 0.601600
# Epoch 83, CIFAR-10 Batch 5:  Loss:     0.0014 Accuracy: 0.592800
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.0007 Accuracy: 0.591800
# Epoch 84, CIFAR-10 Batch 2:  Loss:     0.0026 Accuracy: 0.597600
# Epoch 84, CIFAR-10 Batch 3:  Loss:     0.0001 Accuracy: 0.606600
# Epoch 84, CIFAR-10 Batch 4:  Loss:     0.0060 Accuracy: 0.595200
# Epoch 84, CIFAR-10 Batch 5:  Loss:     0.0009 Accuracy: 0.605200
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.0074 Accuracy: 0.599000
# Epoch 85, CIFAR-10 Batch 2:  Loss:     0.0001 Accuracy: 0.597000
# Epoch 85, CIFAR-10 Batch 3:  Loss:     0.0004 Accuracy: 0.600200
# Epoch 85, CIFAR-10 Batch 4:  Loss:     0.0041 Accuracy: 0.607200
# Epoch 85, CIFAR-10 Batch 5:  Loss:     0.0014 Accuracy: 0.599600
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.0116 Accuracy: 0.600600
# Epoch 86, CIFAR-10 Batch 2:  Loss:     0.0008 Accuracy: 0.601600
# Epoch 86, CIFAR-10 Batch 3:  Loss:     0.0004 Accuracy: 0.594400
# Epoch 86, CIFAR-10 Batch 4:  Loss:     0.0038 Accuracy: 0.604200
# Epoch 86, CIFAR-10 Batch 5:  Loss:     0.0005 Accuracy: 0.598600
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.0004 Accuracy: 0.604400
# Epoch 87, CIFAR-10 Batch 2:  Loss:     0.0000 Accuracy: 0.604200
# Epoch 87, CIFAR-10 Batch 3:  Loss:     0.0002 Accuracy: 0.602200
# Epoch 87, CIFAR-10 Batch 4:  Loss:     0.0129 Accuracy: 0.590200
# Epoch 87, CIFAR-10 Batch 5:  Loss:     0.0020 Accuracy: 0.600600
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.0065 Accuracy: 0.592400
# Epoch 88, CIFAR-10 Batch 2:  Loss:     0.0002 Accuracy: 0.600200
# Epoch 88, CIFAR-10 Batch 3:  Loss:     0.0007 Accuracy: 0.604200
# Epoch 88, CIFAR-10 Batch 4:  Loss:     0.0157 Accuracy: 0.595200
# Epoch 88, CIFAR-10 Batch 5:  Loss:     0.0066 Accuracy: 0.593800
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.0042 Accuracy: 0.596400
# Epoch 89, CIFAR-10 Batch 2:  Loss:     0.0005 Accuracy: 0.608000
# Epoch 89, CIFAR-10 Batch 3:  Loss:     0.0003 Accuracy: 0.603400
# Epoch 89, CIFAR-10 Batch 4:  Loss:     0.0038 Accuracy: 0.598200
# Epoch 89, CIFAR-10 Batch 5:  Loss:     0.0009 Accuracy: 0.607800
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.0014 Accuracy: 0.598400
# Epoch 90, CIFAR-10 Batch 2:  Loss:     0.0001 Accuracy: 0.597600
# Epoch 90, CIFAR-10 Batch 3:  Loss:     0.0034 Accuracy: 0.596200
# Epoch 90, CIFAR-10 Batch 4:  Loss:     0.0012 Accuracy: 0.585600
# Epoch 90, CIFAR-10 Batch 5:  Loss:     0.0007 Accuracy: 0.603800

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.5936511075949367

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
